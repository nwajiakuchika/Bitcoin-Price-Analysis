
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.show()

# %%
df1.set_index('Date',inplace=True)

# %%
df1.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %% [markdown]
# # Bitcoin closing price over time

# %%
plt.figure(figsize=(12,5))
plt.plot(df1['Close'])
plt.title('Bitcoin Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %% [markdown]
# # Trade volume over time

# %%
plt.figure(figsize=(12,5))
plt.plot(df1['Volume'])
plt.title('Bitcoin Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df1.corr(numeric_only=True),annot=True)
plt.title ('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Features and target

# %%
x = df1[['Open','High','Low','Volume']]
y = df1['Close']
x
# Out:
#                     Open          High           Low       Volume
# Date
# 2014-09-17    465.864014    468.174011    452.421997     21056800
# 2014-09-18    456.859985    456.859985    413.104004     34483200
# 2014-09-19    424.102997    427.834991    384.532013     37919700
# 2014-09-20    394.673004    423.295990    389.882996     36863600
# 2014-09-21    408.084991    412.425995    393.181000     26580100
# ...                  ...           ...           ...          ...
# 2022-02-15  42586.464844  44667.218750  42491.035156  22721659051
# 2022-02-16  44578.277344  44578.277344  43456.691406  19792547657
# 2022-02-17  43937.070313  44132.972656  40249.371094  26246662813
# 2022-02-18  40552.132813  40929.152344  39637.617188  23310007704
# 2022-02-19  40022.132813  40246.027344  40010.867188  22263900160
#
# [2713 rows x 4 columns]

# %%
y
# Out:
# Date
# 2014-09-17      457.334015
# 2014-09-18      424.440002
# 2014-09-19      394.795990
# 2014-09-20      408.903992
# 2014-09-21      398.821014
#                   ...
# 2022-02-15    44575.203125
# 2022-02-16    43961.859375
# 2022-02-17    40538.011719
# 2022-02-18    40030.976563
# 2022-02-19    40126.429688
# Name: Close, Length: 2713, dtype: float64

# %% [markdown]
# # Train test and splict

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#                     Open          High           Low       Volume
# Date
# 2015-12-06    389.554993    402.808990    387.088989     77762000
# 2017-06-03   2493.719971   2581.909912   2423.570068   1514950016
# 2021-08-08  44574.437500  45282.351563  43331.910156  36302664750
# 2020-04-18   7092.291504   7269.956543   7089.247070  32447188386
# 2017-02-24   1172.709961   1200.390015   1131.959961    330759008
# ...                  ...           ...           ...          ...
# 2019-03-13   3913.047363   3926.597656   3891.904297   9469184841
# 2017-09-16   3637.750000   3808.840088   3487.790039   1818400000
# 2017-10-21   5996.790039   6194.879883   5965.069824   2207099904
# 2018-04-03   7102.259766   7530.939941   7072.490234   5499700224
# 2017-01-24    910.677002    924.145020    892.286011    111349000
#
# [2170 rows x 4 columns]

# %%
x_test
# Out:
#                     Open          High           Low       Volume
# Date
# 2016-02-05    388.898010    391.093994    385.571991     43825000
# 2018-11-30   4289.088867   4322.976563   3942.822021   6048016717
# 2019-12-05   7253.241699   7743.431641   7232.676758  18816085231
# 2017-04-04   1145.520020   1156.439941   1120.520020    436310016
# 2022-01-14  42598.871094  43346.687500  41982.617188  23577403399
# ...                  ...           ...           ...          ...
# 2017-03-05   1254.290039   1267.290039   1238.060059    134127000
# 2018-01-07  17527.300781  17579.599609  16087.700195  15866000384
# 2021-03-20  58332.261719  60031.285156  58213.296875  50361731222
# 2020-04-12   6858.067871   7119.947266   6811.078125  35759567632
# 2019-12-02   7424.036133   7474.818848   7233.399414  17082040706
#
# [543 rows x 4 columns]

# %%
y_train
# Out:
# Date
# 2015-12-06      388.782990
# 2017-06-03     2515.350098
# 2021-08-08    43798.117188
# 2020-04-18     7257.665039
# 2017-02-24     1173.680054
#                   ...
# 2019-03-13     3906.717285
# 2017-09-16     3625.040039
# 2017-10-21     6031.600098
# 2018-04-03     7456.109863
# 2017-01-24      892.687012
# Name: Close, Length: 2170, dtype: float64

# %%
y_test
# Out:
# Date
# 2016-02-05      386.549011
# 2018-11-30     4017.268555
# 2019-12-05     7448.307617
# 2017-04-04     1133.250000
# 2022-01-14    43099.699219
#                   ...
# 2017-03-05     1267.119995
# 2018-01-07    16477.599609
# 2021-03-20    58313.644531
# 2020-04-12     6971.091797
# 2019-12-02     7321.988281
# Name: Close, Length: 543, dtype: float64

# %% [markdown]
# # Model training

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Making prediction

# %%
y_pred = model.predict(x_test)
y_pred[:10]
# Out:
# array([  389.787434  ,  4087.83135736,  7649.23298068,  1136.59167491,
#        42650.22284707,   244.81239299,   423.95065615, 17906.07116354,
#        57717.03582118, 40641.58102552])

# %% [markdown]
# # Evaluating the model

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print("R2 score:",score)
# Out:
# R2 score: 0.9996103476619451

# %% [markdown]
# # Actual vs predicted price

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Close Price')
plt.ylabel('Predicted Close Price')
plt.title('Actual vs Predicted Bitcoin Price')
plt.show()

# %% [markdown]
# # Feature importance

# %%
importance = pd.DataFrame({
    'feature':x.columns,
    'Coefficient':model.coef_
})
importance = importance.sort_values(
    by = 'Coefficient',
    ascending = False
)
print(importance)
# Out:
#   feature   Coefficient
# 1    High  8.986009e-01
# 2     Low  6.117566e-01
# 3  Volume  4.625072e-10
# 0    Open -5.164100e-01

# %% [markdown]
# # Summary

# %%
# This project analysed bitcoin historical price data to
# understand the trends and market behavior.visualization
# were used to explore bitcoin closing price,trading volume
# and feature relationships.

# %% [markdown]
# # Conclusion

# %%
# The project show how machine learning can be use to 
# analyze and predict bitcoin prices using historical market data.
